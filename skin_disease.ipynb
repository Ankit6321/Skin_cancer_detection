# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
BATCH_SIZE = 32
IMAGE_WIDTH = 256
IMAGE_HEIGHT = 192
EPOCHS = 50

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "SkinDisease",
    seed=99,
    shuffle=True,
    image_size=(IMAGE_HEIGHT,IMAGE_WIDTH),
    batch_size=BATCH_SIZE
)
# Out:
# Found 14951 files belonging to 22 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Acne',
#  'Actinic_Keratosis',
#  'Benign_tumors',
#  'Bullous',
#  'Candidiasis',
#  'DrugEruption',
#  'Eczema',
#  'Infestations_Bites',
#  'Lichen',
#  'Lupus',
#  'Moles',
#  'Normal',
#  'Psoriasis',
#  'Rosacea',
#  'Seborrh_Keratoses',
#  'SkinCancer',
#  'Sunlight_Damage',
#  'Tinea',
#  'Vascular_Tumors',
#  'Vasculitis',
#  'Vitiligo',
#  'Warts']

# %%
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (32, 192, 256, 3)
# [11  2  5 21 11  5  8  6 18 18  4  2 11 11  3  2 17  6 20  7  3 12 12 20
#  11  2 15 11 17 19  1 11]

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in dataset.take(1):
    for i in range(1):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")
